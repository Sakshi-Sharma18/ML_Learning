# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
df=pd.read_csv("https://raw.githubusercontent.com/Premalatha-success/Data-Visualization/main/Automobile.csv")

# %%
df.head(5) ### display first 5 rows
# Out:
#    symboling  normalized_losses         make fuel_type aspiration  \
# 0          3                168  alfa-romero       gas        std
# 1          3                168  alfa-romero       gas        std
# 2          1                168  alfa-romero       gas        std
# 3          2                164         audi       gas        std
# 4          2                164         audi       gas        std
#
#   number_of_doors   body_style drive_wheels engine_location  wheel_base  ...  \
# 0             two  convertible          rwd           front        88.6  ...
# 1             two  convertible          rwd           front        88.6  ...
# 2             two    hatchback          rwd           front        94.5  ...
# 3            four        sedan          fwd           front        99.8  ...
# 4            four        sedan          4wd           front        99.4  ...
#
#    engine_size  fuel_system  bore  stroke compression_ratio horsepower  \
# ...

# %%
df.shape ### no.of rows and colomns
# Out:
# (201, 26)

# %%
df.isnull().sum() ### to see if there are any missing values in the dataset
# Out:
# symboling              0
# normalized_losses      0
# make                   0
# fuel_type              0
# aspiration             0
# number_of_doors        0
# body_style             0
# drive_wheels           0
# engine_location        0
# wheel_base             0
# length                 0
# width                  0
# height                 0
# curb_weight            0
# engine_type            0
# number_of_cylinders    0
# engine_size            0
# fuel_system            0
# bore                   0
# stroke                 0
# compression_ratio      0
# horsepower             0
# peak_rpm               0
# city_mpg               0
# highway_mpg            0
# price                  0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 201 entries, 0 to 200
# Data columns (total 26 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   symboling            201 non-null    int64
#  1   normalized_losses    201 non-null    int64
#  2   make                 201 non-null    object
#  3   fuel_type            201 non-null    object
#  4   aspiration           201 non-null    object
#  5   number_of_doors      201 non-null    object
#  6   body_style           201 non-null    object
#  7   drive_wheels         201 non-null    object
#  8   engine_location      201 non-null    object
#  9   wheel_base           201 non-null    float64
#  10  length               201 non-null    float64
#  11  width                201 non-null    float64
#  12  height               201 non-null    float64
#  13  curb_weight          201 non-null    int64
#  14  engine_type          201 non-null    object
# ...

# %%
sns.relplot(x="city_mpg", y="highway_mpg", hue="body_style", data = df)

# %%
sns.catplot(x="body_style", y="symboling", data=df)

# %%
sns.catplot(x="body_style", y="symboling", jitter = False,  data=df)

# %%
sns.catplot(x="body_style", y="symboling", hue="fuel_system",  data=df)

# %%
sns.catplot(x="body_style", y="symboling", kind="swarm" ,s=1,  data=df)

# %%
sns.catplot(x="body_style", y="symboling", hue="fuel_system", kind="swarm" ,s=1,  data=df)

# %%
sns.catplot(x="body_style", y="symboling", kind="box" ,  data=df)

# %%
sns.catplot(x="body_style", y="symboling", hue="fuel_system" , kind="box" ,  data=df)

# %%
sns.catplot(x="body_style", y="symboling", hue="fuel_system" , kind="violin" ,  data=df)

# %%
sns.catplot(x="body_style", y="symboling", hue="fuel_type" , kind="violin", split=True ,  data=df)

# %%
sns.catplot(x="body_style", y="symboling", hue="fuel_type" , kind="bar" ,  data=df)

# %%
sns.catplot(x="body_style", y="symboling", hue="fuel_type" , kind="point" ,  data=df)
